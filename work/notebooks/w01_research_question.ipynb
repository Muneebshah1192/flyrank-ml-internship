# %% [markdown]
# <a href="https://colab.research.google.com/github/Muneebshah1192/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# **Lane:** Discoverability & Ranking Decline (Content Decay)
#
# **Why:** Identifying which pages are losing organic search visibility before their traffic bottoms out is a high-ROI business problem. Instead of relying on manual audits or simple age-based rules, utilizing ML to find the non-linear relationships between a page's age, historical CTR, and search impressions provides a highly actionable, data-driven signal for the content team.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# * **The Decision:** Which specific articles or pages should the editorial team prioritize for an SEO refresh or rewrite this month?
# * **The Action:** The content team assigns an editor to update, re-optimize, or expand the flagged pages to recover lost search visibility.
# * **The Cost of a wrong call:** False positives waste expensive editorial hours on pages that are naturally fluctuating but technically fine. False negatives result in high-value pages slowly bleeding impressions and dropping out of the top search results entirely unnoticed.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
import glob
import os

# Locate the starter CSV in the data folder (going up two directories from work/notebooks)
data_files = glob.glob("../../data/*.csv")

if not data_files:
    print("Error: Could not find the starter CSV in the data folder. Please check your path.")
else:
    # Load the first available CSV from the starter data
    file_path = data_files[0]
    df = pd.read_csv(file_path)

    total_records = len(df)

    # Safely extract metrics assuming standard search console column naming
    impressions_col = next((col for col in df.columns if 'impression' in col.lower()), None)
    ctr_col = next((col for col in df.columns if 'ctr' in col.lower()), None)

    print("--- Data Validation for Content Decay Lane ---")
    print(f"Total search records available for analysis: {total_records:,}")

    if impressions_col:
        avg_impressions = df[impressions_col].mean()
        print(f"Average impressions across dataset: {avg_impressions:,.1f}")

    if ctr_col:
        low_ctr_count = len(df[df[ctr_col] < 0.02])
        print(f"Records with critically low CTR (< 2%): {low_ctr_count:,} pages at risk")
# Out:
# Error: Could not find the starter CSV in the data folder. Please check your path.

# %%
import pandas as pd
import glob
import os

# 1. Download the repository into Colab's temporary environment
if not os.path.exists('flyrank-ml-internship'):
    # !git clone https://github.com/Muneebshah1192/flyrank-ml-internship.git

# 2. Locate the starter CSV in the newly downloaded data folder
data_files = glob.glob("flyrank-ml-internship/data/*.csv")

if not data_files:
    print("Error: Could not find the starter CSV. Please check the repository structure.")
else:
    # Load the first available CSV from the starter data
    file_path = data_files[0]
    df = pd.read_csv(file_path)

    total_records = len(df)

    # Safely extract metrics assuming standard search console column naming
    impressions_col = next((col for col in df.columns if 'impression' in col.lower()), None)
    ctr_col = next((col for col in df.columns if 'ctr' in col.lower()), None)

    print(f"--- Data Validation for Content Decay Lane ---")
    print(f"Total search records available for analysis: {total_records:,}")

    if impressions_col:
        avg_impressions = df[impressions_col].mean()
        print(f"Average impressions across dataset: {avg_impressions:,.1f}")

    if ctr_col:
        low_ctr_count = len(df[df[ctr_col] < 0.02])
        print(f"Records with critically low CTR (< 2%): {low_ctr_count:,} pages at risk")
# Out:
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 111, done.
# remote: Counting objects: 100% (111/111), done.
# remote: Compressing objects: 100% (82/82), done.
# remote: Total 111 (delta 28), reused 77 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (111/111), 1.84 MiB | 6.36 MiB/s, done.
# Resolving deltas: 100% (28/28), done.
# Error: Could not find the starter CSV. Please check the repository structure.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# * **What I can claim:** I can claim that a page exhibits historical traffic patterns (based on measured impressions and CTR) that are directionally associated with a decline, providing strong decision-support for the editorial team.
# * **What I cannot claim:** I cannot claim causal proof of *why* Google's algorithm dropped the ranking, nor can I predict Google's exact future algorithm updates or guarantee that refreshing the page will perfectly restore traffic.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
